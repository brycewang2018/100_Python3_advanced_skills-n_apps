# %% [markdown]
# <a href="https://colab.research.google.com/github/byrcewang/Python-advanced_tricks/blob/main/1-Iterable_Iterator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Iterable, Iterator

# %%
from collections.abc import Iterable, Iterator

# Create a list of elements
list1 = [1, 2, 3, 4, 5]

# Check if the list is iterable
is_iterable = isinstance(list1, Iterable)
print(is_iterable)  # True

# Get an iterator for the list
iterator = list1.__iter__()

# Iterate over the elements of the list
while True:
    try:
        element = next(iterator)
        print(element)
    except StopIteration:
        break
# Out:
# True
# 1
# 2
# 3
# 4
# 5

# %%
# List
l = [1, 2, 3, 4, 5]

for n in l:
  print(n, end=', ')
# Out:
# 1, 2, 3, 4, 5,

# %%
from collections.abc import Iterable, Iterator
isinstance(l, Iterable)
# Out:
# True

# %%
isinstance(l, Iterator)
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
iter(l)

# %%
iter(l)

# %%
l.__iter__()

# %%
Iterable.__abstractmethods__
# Out:
# frozenset({'__iter__'})

# %%
it = iter(l)

# %%
next(it)
# Out:
# 1

# %%
next(it)
# Out:
# 2

# %%
next(it)
# Out:
# 3

# %%
next(it)
# Out:
# 4

# %%
next(it)
# Out:
# 5

# %%
next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-21-bc1ab118995a> in <cell line: 1>()
# ----> 1 next(it)
#
# StopIteration:

# %%
it.__next__() ## next(it)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-22-74e64ed6c80d> in <cell line: 1>()
# ----> 1 it.__next__()
#
# StopIteration:

# %%
it=iter(l)
print(next(it))
list(it)
# Out:
# 1
# [2, 3, 4, 5]

# %%
list(it)
# Out:
# []

# %%
it = iter([1, 2, 3, 4])
for n in it:
  print(n, end=", ")
# Out:
# 1, 2, 3, 4,

# %%
it.__iter__()

# %%
it.__iter__() is it
# Out:
# True
